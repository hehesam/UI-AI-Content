# %%
import pandas as pd

# %%
series1 = pd.Series([1,2,3,4])
print(series1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data = pd.read_csv('FL_insurance_sample.csv')

# %%
df = pd.DataFrame({
    "column1": [1,4,8,7,9],
    "column2": ['a','ehsan','with','Hello','b'],
    "column3": [2.23,3.23,2.36,45.23,47.52],
    "column4": [True,False,True,False,True]
})
print(df)
# Out:
#    column1 column2  column3  column4
# 0        1       a     2.23     True
# 1        4   ehsan     3.23    False
# 2        8    with     2.36     True
# 3        7   Hello    45.23    False
# 4        9       b    47.52     True

# %%
df.to_numpy()
# Out:
# array([[1, 'a', 2.23, True],
#        [4, 'ehsan', 3.23, False],
#        [8, 'with', 2.36, True],
#        [7, 'Hello', 45.23, False],
#        [9, 'b', 47.52, True]], dtype=object)

# %%
df.describe()
# Out:
#         column1    column3
# count  5.000000   5.000000
# mean   5.800000  20.114000
# std    3.271085  23.989653
# min    1.000000   2.230000
# 25%    4.000000   2.360000
# 50%    7.000000   3.230000
# 75%    8.000000  45.230000
# max    9.000000  47.520000

# %%
data.describe()
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36634 entries, 0 to 36633
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   policyID            36634 non-null  int64
#  1   statecode           36634 non-null  object
#  2   county              36634 non-null  object
#  3   eq_site_limit       36634 non-null  float64
#  4   hu_site_limit       36634 non-null  float64
#  5   fl_site_limit       36634 non-null  float64
#  6   fr_site_limit       36634 non-null  float64
#  7   tiv_2011            36634 non-null  float64
#  8   tiv_2012            36634 non-null  float64
#  9   eq_site_deductible  36634 non-null  float64
#  10  hu_site_deductible  36634 non-null  float64
#  11  fl_site_deductible  36634 non-null  float64
#  12  fr_site_deductible  36634 non-null  int64
#  13  point_latitude      36634 non-null  float64
#  14  point_longitude     36634 non-null  float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   column1  5 non-null      int64
#  1   column2  5 non-null      object
#  2   column3  5 non-null      float64
#  3   column4  5 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 253.0+ bytes

# %%
df["column1"].value_counts()
# Out:
# 8    1
# 1    1
# 4    1
# 9    1
# 7    1
# Name: column1, dtype: int64

# %%
df.T
# Out:
#             0      1     2      3      4
# column1     1      4     8      7      9
# column2     a  ehsan  with  Hello      b
# column3  2.23   3.23  2.36  45.23  47.52
# column4  True  False  True  False   True

# %%
data.T
# Out:
#                           0            1            2            3      \
# policyID                 119736       448094       206893       333743
# statecode                    FL           FL           FL           FL
# county              CLAY COUNTY  CLAY COUNTY  CLAY COUNTY  CLAY COUNTY
# eq_site_limit          498960.0    1322376.3     190724.4          0.0
# hu_site_limit          498960.0    1322376.3     190724.4     79520.76
# fl_site_limit          498960.0    1322376.3     190724.4          0.0
# fr_site_limit          498960.0    1322376.3     190724.4          0.0
# tiv_2011               498960.0    1322376.3     190724.4     79520.76
# tiv_2012               792148.9   1438163.57    192476.78     86854.48
# eq_site_deductible          0.0          0.0          0.0          0.0
# hu_site_deductible       9979.2          0.0          0.0          0.0
# fl_site_deductible          0.0          0.0          0.0          0.0
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    column4  column3 column2  column1
# 0     True     2.23       a        1
# 1    False     3.23   ehsan        4
# 2     True     2.36    with        8
# 3    False    45.23   Hello        7
# 4     True    47.52       b        9

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#    column1 column2  column3  column4
# 0        1       a     2.23     True
# 1        4   ehsan     3.23    False
# 2        8    with     2.36     True
# 3        7   Hello    45.23    False
# 4        9       b    47.52     True

# %%
df.sort_values(by= "column3")
# Out:
#    column1 column2  column3  column4
# 0        1       a     2.23     True
# 2        8    with     2.36     True
# 1        4   ehsan     3.23    False
# 3        7   Hello    45.23    False
# 4        9       b    47.52     True

# %%
df.loc[[0,4],['column2']]
# Out:
#   column2
# 0       a
# 4       b

# %%
data.loc[[0,9],['policyID']]
# Out:
#    policyID
# 0    119736
# 9    142071

# %%
df.iloc[2:5, 0:3]
# Out:
#    column1 column2  column3
# 2        8    with     2.36
# 3        7   Hello    45.23
# 4        9       b    47.52

# %%
data.iloc[2:15, 0:20]
# Out:
#     policyID statecode       county  eq_site_limit  hu_site_limit  \
# 2     206893        FL  CLAY COUNTY       190724.4      190724.40
# 3     333743        FL  CLAY COUNTY            0.0       79520.76
# 4     172534        FL  CLAY COUNTY            0.0      254281.50
# 5     785275        FL  CLAY COUNTY            0.0      515035.62
# 6     995932        FL  CLAY COUNTY            0.0    19260000.00
# 7     223488        FL  CLAY COUNTY       328500.0      328500.00
# 8     433512        FL  CLAY COUNTY       315000.0      315000.00
# 9     142071        FL  CLAY COUNTY       705600.0      705600.00
# 10    253816        FL  CLAY COUNTY       831498.3      831498.30
# 11    894922        FL  CLAY COUNTY            0.0       24059.09
# 12    422834        FL  CLAY COUNTY            0.0       48115.94
# 13    582721        FL  CLAY COUNTY            0.0       28869.12
# 14    842700        FL  CLAY COUNTY            0.0       56135.64
#
# ...

# %%
df[df['column1'] > 4]
# Out:
#    column1 column2  column3  column4
# 2        8    with     2.36     True
# 3        7   Hello    45.23    False
# 4        9       b    47.52     True

# %%
df.iat[2,1] = 100

# %%
df.iat[0,0] = 25

# %%
df.T
# Out:
#             0      1     2      3      4
# column1    25      4     8      7      9
# column2     a  ehsan   100  Hello      b
# column3  2.23   3.23  2.36  45.23  47.52
# column4  True  False  True  False   True

# %%
df.dropna(inplace=True)

# %%
df.T
# Out:
#             0      1     2      3      4
# column1    25      4     8      7      9
# column2     a  ehsan   100  Hello      b
# column3  2.23   3.23  2.36  45.23  47.52
# column4  True  False  True  False   True

# %%
ab = pd.DataFrame({
    "column1": [1,2,3,4,5],
    "column2": [2,3,45,67,89]
})

# %%
ab.fillna(value=8)
# Out:
#    column1  column2
# 0        1        2
# 1        2        3
# 2        3       45
# 3        4       67
# 4        5       89

# %%
data.isna()
# Out:
#        policyID  statecode  county  eq_site_limit  hu_site_limit  \
# 0         False      False   False          False          False
# 1         False      False   False          False          False
# 2         False      False   False          False          False
# 3         False      False   False          False          False
# 4         False      False   False          False          False
# ...         ...        ...     ...            ...            ...
# 36629     False      False   False          False          False
# 36630     False      False   False          False          False
# 36631     False      False   False          False          False
# 36632     False      False   False          False          False
# 36633     False      False   False          False          False
#
#        fl_site_limit  fr_site_limit  tiv_2011  tiv_2012  eq_site_deductible  \
# 0              False          False     False     False               False
# ...

# %%
df.isna()
# Out:
#    column1  column2  column3  column4
# 0    False    False    False    False
# 1    False    False    False    False
# 2    False    False    False    False
# 3    False    False    False    False
# 4    False    False    False    False

# %%
d1 = {
    'subject_id': ['1','2','3','4','5'],
    'student_name': ['Brian','William','Lillian','Grace','Calbe']
}
df1 = pd.DataFrame(d1, columns=['subject_id','student_name'])

# %%
d2 = {
    'subject_id': ['1','2','3','4','5'],
    'student_name': ['John','Emily','Kate','Joseph','Dennis']
}
df2 = pd.DataFrame(d2, columns=['subject_id','student_name'])

# %%
pd.merge(df1, df2, on='subject_id')
# Out:
#   subject_id student_name_x student_name_y
# 0          1          Brian           John
# 1          2        William          Emily
# 2          3         Lilian           Kate
# 3          4          Grace         Joseph
# 4          5          Calbe         Dennis

# %%
pd.concat([df1, df2])
# Out:
#   subject_id student_name
# 0          1        Brian
# 1          2      William
# 2          3       Lilian
# 3          4        Grace
# 4          5        Calbe
# 0          1         John
# 1          2        Emily
# 2          3         Kate
# 3          4       Joseph
# 4          5       Dennis

# %%
df3 = pd.DataFrame({
    "column1": [1,2,3,4,5],
    "column2": [6,7,8,9,10]
})

# %%
df3.T
# Out:
#          0  1  2  3   4
# column1  1  2  3  4   5
# column2  6  7  8  9  10

# %%
df3.groupby("column2").sum()
# Out:
#          column1
# column2
# 6              1
# 7              2
# 8              3
# 9              4
# 10             5

# %%
df["grade"] = ["a","b","b","e","a"]
df["grade"] =df["grade"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   column1  5 non-null      int64
#  1   column2  5 non-null      object
#  2   column3  5 non-null      float64
#  3   column4  5 non-null      bool
#  4   grade    5 non-null      category
# dtypes: bool(1), category(1), float64(1), int64(1), object(1)
# memory usage: 474.0+ bytes

# %%
df.T
# Out:
#             0      1     2      3      4
# column1    25      4     8      7      9
# column2     a  ehsan   100  Hello      b
# column3  2.23   3.23  2.36  45.23  47.52
# column4  True  False  True  False   True
# grade       a      b     b      e      a

# %%
df.corr()
# Out:
#           column1   column3   column4
# column1  1.000000 -0.295322  0.563338
# column3 -0.295322  1.000000 -0.156625
# column4  0.563338 -0.156625  1.000000

# %%
df1.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("myFirstDataframe.csv")
